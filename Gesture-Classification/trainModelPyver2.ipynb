# %%
from pycaret.classification import *
import pandas as pd
import os

# %%
data_dir = "C:/Users/USER/Desktop/Gesture Data"
data_df = pd.read_csv("data_df.csv")

# %%
data_df.head()
# Out:
#    Time  imu0_ax  imu0_ay  imu0_az  imu1_ax  imu1_ay  imu1_az  imu2_ax  \
# 0     0    19.92     18.0   -18.45    17.38     0.23   -19.85    17.47
# 1     1    19.85     20.0   -16.91    14.76     0.23   -19.69    14.94
# 2     2    19.77     20.0   -15.36    12.14     0.23   -19.54    12.42
# 3     3    19.69     20.0   -13.81     9.52     0.23   -19.39     9.89
# 4     4    19.62     20.0   -12.27     6.90     0.23   -19.23     7.36
#
#    imu2_ay  imu2_az  imu3_ax  imu3_ay  imu3_az   Gesture
# 0    -1.82   -19.96    17.55    -0.57   -13.61  Backward
# 1    -2.83   -19.92    15.10    -0.88    -7.22  Backward
# 2    -3.83   -19.89    12.64    -1.19    -0.84  Backward
# 3    -4.84   -19.85    10.19    -1.49     5.55  Backward
# 4    -5.84   -19.81     7.74    -1.80    11.94  Backward

# %%
data_df.dtypes
# Out:
# Time         int64
# imu0_ax    float64
# imu0_ay    float64
# imu0_az    float64
# imu1_ax    float64
# imu1_ay    float64
# imu1_az    float64
# imu2_ax    float64
# imu2_ay    float64
# imu2_az    float64
# imu3_ax    float64
# imu3_ay    float64
# imu3_az    float64
# Gesture     object
# dtype: object

# %%
features = ['imu0_ax', 'imu0_ay', 'imu0_az', 'imu1_ax', 'imu1_ay', 'imu1_az', 'imu2_ax', 'imu2_ay', 'imu2_az', 'imu3_ax', 'imu3_ay', 'imu3_az']

# %%
# train using pycaret svm
clf = setup(data=data_df, target="Gesture", numeric_features=features, session_id=123)
svm = create_model("svm")
# Out:
# <style type="text/css">
# #T_7f64a_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7f64a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f64a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7f64a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f64a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7f64a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7f64a_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_7f64a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7f64a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7f64a_row1_col1" class="data row1 col1" >Gesture</td>
#     </tr>
#     <tr>
#       <th id="T_7f64a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7f64a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_7f64a_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_7f64a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7f64a_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_7f64a_row3_col1" class="data row3 col1" >Backward: 0, Default: 1, Down: 2, Forward: 3, Left: 4, Right: 5, Up: 6</td>
#     </tr>
#     <tr>
#       <th id="T_7f64a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7f64a_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_7f64a_row4_col1" class="data row4 col1" >(2400, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_7f64a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7f64a_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_7f64a_row5_col1" class="data row5 col1" >(2400, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_7f64a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7f64a_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_7f64a_row6_col1" class="data row6 col1" >(1680, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_7f64a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7f64a_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_7f64a_row7_col1" class="data row7 col1" >(720, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_7f64a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7f64a_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_7f64a_row8_col1" class="data row8 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_7f64a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7f64a_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_7f64a_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7f64a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7f64a_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_7f64a_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_7f64a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7f64a_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_7f64a_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_7f64a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7f64a_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_7f64a_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_7f64a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7f64a_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_7f64a_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_7f64a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7f64a_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_7f64a_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7f64a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7f64a_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_7f64a_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_7f64a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7f64a_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_7f64a_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7f64a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7f64a_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_7f64a_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7f64a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7f64a_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_7f64a_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_7f64a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7f64a_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_7f64a_row19_col1" class="data row19 col1" >4f12</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_69cec_row10_col0, #T_69cec_row10_col1, #T_69cec_row10_col2, #T_69cec_row10_col3, #T_69cec_row10_col4, #T_69cec_row10_col5, #T_69cec_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_69cec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69cec_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_69cec_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_69cec_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_69cec_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_69cec_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_69cec_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_69cec_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69cec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69cec_row0_col0" class="data row0 col0" >0.5357</td>
#       <td id="T_69cec_row0_col1" class="data row0 col1" >0.0000</td>
#       <td id="T_69cec_row0_col2" class="data row0 col2" >0.5357</td>
#       <td id="T_69cec_row0_col3" class="data row0 col3" >0.6427</td>
#       <td id="T_69cec_row0_col4" class="data row0 col4" >0.4940</td>
#       <td id="T_69cec_row0_col5" class="data row0 col5" >0.4582</td>
#       <td id="T_69cec_row0_col6" class="data row0 col6" >0.4851</td>
#     </tr>
#     <tr>
#       <th id="T_69cec_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_69cec_row1_col0" class="data row1 col0" >0.4464</td>
#       <td id="T_69cec_row1_col1" class="data row1 col1" >0.0000</td>
#       <td id="T_69cec_row1_col2" class="data row1 col2" >0.4464</td>
#       <td id="T_69cec_row1_col3" class="data row1 col3" >0.5238</td>
#       <td id="T_69cec_row1_col4" class="data row1 col4" >0.4330</td>
#       <td id="T_69cec_row1_col5" class="data row1 col5" >0.3546</td>
#       <td id="T_69cec_row1_col6" class="data row1 col6" >0.3624</td>
#     </tr>
#     <tr>
#       <th id="T_69cec_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_69cec_row2_col0" class="data row2 col0" >0.4405</td>
#       <td id="T_69cec_row2_col1" class="data row2 col1" >0.0000</td>
#       <td id="T_69cec_row2_col2" class="data row2 col2" >0.4405</td>
#       <td id="T_69cec_row2_col3" class="data row2 col3" >0.3919</td>
#       <td id="T_69cec_row2_col4" class="data row2 col4" >0.3991</td>
#       <td id="T_69cec_row2_col5" class="data row2 col5" >0.3479</td>
#       <td id="T_69cec_row2_col6" class="data row2 col6" >0.3566</td>
#     </tr>
#     <tr>
#       <th id="T_69cec_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_69cec_row3_col0" class="data row3 col0" >0.4524</td>
#       <td id="T_69cec_row3_col1" class="data row3 col1" >0.0000</td>
#       <td id="T_69cec_row3_col2" class="data row3 col2" >0.4524</td>
#       <td id="T_69cec_row3_col3" class="data row3 col3" >0.4798</td>
#       <td id="T_69cec_row3_col4" class="data row3 col4" >0.4413</td>
#       <td id="T_69cec_row3_col5" class="data row3 col5" >0.3606</td>
#       <td id="T_69cec_row3_col6" class="data row3 col6" >0.3761</td>
#     </tr>
#     <tr>
#       <th id="T_69cec_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_69cec_row4_col0" class="data row4 col0" >0.4583</td>
#       <td id="T_69cec_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_69cec_row4_col2" class="data row4 col2" >0.4583</td>
#       <td id="T_69cec_row4_col3" class="data row4 col3" >0.4904</td>
#       <td id="T_69cec_row4_col4" class="data row4 col4" >0.4296</td>
#       <td id="T_69cec_row4_col5" class="data row4 col5" >0.3688</td>
#       <td id="T_69cec_row4_col6" class="data row4 col6" >0.3800</td>
#     </tr>
#     <tr>
#       <th id="T_69cec_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_69cec_row5_col0" class="data row5 col0" >0.3274</td>
#       <td id="T_69cec_row5_col1" class="data row5 col1" >0.0000</td>
#       <td id="T_69cec_row5_col2" class="data row5 col2" >0.3274</td>
#       <td id="T_69cec_row5_col3" class="data row5 col3" >0.5027</td>
#       <td id="T_69cec_row5_col4" class="data row5 col4" >0.3243</td>
#       <td id="T_69cec_row5_col5" class="data row5 col5" >0.2140</td>
#       <td id="T_69cec_row5_col6" class="data row5 col6" >0.2419</td>
#     </tr>
#     <tr>
#       <th id="T_69cec_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_69cec_row6_col0" class="data row6 col0" >0.4048</td>
#       <td id="T_69cec_row6_col1" class="data row6 col1" >0.0000</td>
#       <td id="T_69cec_row6_col2" class="data row6 col2" >0.4048</td>
#       <td id="T_69cec_row6_col3" class="data row6 col3" >0.4293</td>
#       <td id="T_69cec_row6_col4" class="data row6 col4" >0.3925</td>
#       <td id="T_69cec_row6_col5" class="data row6 col5" >0.3045</td>
#       <td id="T_69cec_row6_col6" class="data row6 col6" >0.3114</td>
#     </tr>
#     <tr>
#       <th id="T_69cec_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_69cec_row7_col0" class="data row7 col0" >0.4345</td>
#       <td id="T_69cec_row7_col1" class="data row7 col1" >0.0000</td>
#       <td id="T_69cec_row7_col2" class="data row7 col2" >0.4345</td>
#       <td id="T_69cec_row7_col3" class="data row7 col3" >0.5975</td>
#       <td id="T_69cec_row7_col4" class="data row7 col4" >0.4485</td>
#       <td id="T_69cec_row7_col5" class="data row7 col5" >0.3406</td>
#       <td id="T_69cec_row7_col6" class="data row7 col6" >0.3576</td>
#     </tr>
#     <tr>
#       <th id="T_69cec_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_69cec_row8_col0" class="data row8 col0" >0.4524</td>
#       <td id="T_69cec_row8_col1" class="data row8 col1" >0.0000</td>
#       <td id="T_69cec_row8_col2" class="data row8 col2" >0.4524</td>
#       <td id="T_69cec_row8_col3" class="data row8 col3" >0.5099</td>
#       <td id="T_69cec_row8_col4" class="data row8 col4" >0.4173</td>
#       <td id="T_69cec_row8_col5" class="data row8 col5" >0.3632</td>
#       <td id="T_69cec_row8_col6" class="data row8 col6" >0.3781</td>
#     </tr>
#     <tr>
#       <th id="T_69cec_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_69cec_row9_col0" class="data row9 col0" >0.5595</td>
#       <td id="T_69cec_row9_col1" class="data row9 col1" >0.0000</td>
#       <td id="T_69cec_row9_col2" class="data row9 col2" >0.5595</td>
#       <td id="T_69cec_row9_col3" class="data row9 col3" >0.5549</td>
#       <td id="T_69cec_row9_col4" class="data row9 col4" >0.5276</td>
#       <td id="T_69cec_row9_col5" class="data row9 col5" >0.4870</td>
#       <td id="T_69cec_row9_col6" class="data row9 col6" >0.4944</td>
#     </tr>
#     <tr>
#       <th id="T_69cec_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_69cec_row10_col0" class="data row10 col0" >0.4512</td>
#       <td id="T_69cec_row10_col1" class="data row10 col1" >0.0000</td>
#       <td id="T_69cec_row10_col2" class="data row10 col2" >0.4512</td>
#       <td id="T_69cec_row10_col3" class="data row10 col3" >0.5123</td>
#       <td id="T_69cec_row10_col4" class="data row10 col4" >0.4307</td>
#       <td id="T_69cec_row10_col5" class="data row10 col5" >0.3600</td>
#       <td id="T_69cec_row10_col6" class="data row10 col6" >0.3744</td>
#     </tr>
#     <tr>
#       <th id="T_69cec_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_69cec_row11_col0" class="data row11 col0" >0.0607</td>
#       <td id="T_69cec_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_69cec_row11_col2" class="data row11 col2" >0.0607</td>
#       <td id="T_69cec_row11_col3" class="data row11 col3" >0.0702</td>
#       <td id="T_69cec_row11_col4

# %%
plot_model(svm, plot="confusion_matrix")

# %%
clf = setup(data=data_df, target="Gesture",numeric_features=features, session_id=123, experiment_name="experiment_1")
best_model = compare_models()
print(best_model)
# Out:
# <style type="text/css">
# #T_4e7f9_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4e7f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e7f9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4e7f9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e7f9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e7f9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4e7f9_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_4e7f9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4e7f9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4e7f9_row1_col1" class="data row1 col1" >Gesture</td>
#     </tr>
#     <tr>
#       <th id="T_4e7f9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4e7f9_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4e7f9_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_4e7f9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4e7f9_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_4e7f9_row3_col1" class="data row3 col1" >Backward: 0, Default: 1, Down: 2, Forward: 3, Left: 4, Right: 5, Up: 6</td>
#     </tr>
#     <tr>
#       <th id="T_4e7f9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4e7f9_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_4e7f9_row4_col1" class="data row4 col1" >(2400, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_4e7f9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4e7f9_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_4e7f9_row5_col1" class="data row5 col1" >(2400, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_4e7f9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4e7f9_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_4e7f9_row6_col1" class="data row6 col1" >(1680, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_4e7f9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4e7f9_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_4e7f9_row7_col1" class="data row7 col1" >(720, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_4e7f9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4e7f9_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_4e7f9_row8_col1" class="data row8 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_4e7f9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4e7f9_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_4e7f9_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4e7f9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4e7f9_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_4e7f9_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4e7f9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4e7f9_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_4e7f9_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4e7f9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4e7f9_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_4e7f9_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4e7f9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4e7f9_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_4e7f9_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_4e7f9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4e7f9_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_4e7f9_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4e7f9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4e7f9_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_4e7f9_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4e7f9_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4e7f9_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_4e7f9_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4e7f9_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4e7f9_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_4e7f9_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4e7f9_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4e7f9_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_4e7f9_row18_col1" class="data row18 col1" >experiment_1</td>
#     </tr>
#     <tr>
#       <th id="T_4e7f9_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4e7f9_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_4e7f9_row19_col1" class="data row19 col1" >ee2e</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_042b2 th {
#   text-align: left;
# }
# #T_042b2_row0_col0, #T_042b2_row1_col0, #T_042b2_row1_col1, #T_042b2_row1_col3, #T_042b2_row1_col4, #T_042b2_row1_col5, #T_042b2_row1_col6, #T_042b2_row1_col7, #T_042b2_row2_col0, #T_042b2_row2_col1, #T_042b2_row2_col3, #T_042b2_row2_col4, #T_042b2_row2_col5, #T_042b2_row2_col6, #T_042b2_row2_col7, #T_042b2_row3_col0, #T_042b2_row3_col1, #T_042b2_row3_col3, #T_042b2_row3_col4, #T_042b2_row3_col5, #T_042b2_row3_col6, #T_042b2_row3_col7, #T_042b2_row4_col0, #T_042b2_row4_col1, #T_042b2_row4_col3, #T_042b2_row4_col4, #T_042b2_row4_col5, #T_042b2_row4_col6, #T_042b2_row4_col7, #T_042b2_row5_col0, #T_042b2_row5_col1, #T_042b2_row5_col3, #T_042b2_row5_col4, #T_042b2_row5_col5, #T_042b2_row5_col6, #T_042b2_row5_col7, #T_042b2_row6_col0, #T_042b2_row6_col1, #T_042b2_row6_col3, #T_042b2_row6_col4, #T_042b2_row6_col5, #T_042b2_row6_col6, #T_042b2_row6_col7, #T_042b2_row7_col0, #T_042b2_row7_col1, #T_042b2_row7_col3, #T_042b2_row7_col4, #T_042b2_row7_col5, #T_042b2_row7_col6, #T_042b2_row7_col7, #T_042b2_row8_col0, #T_042b2_row8_col1, #T_042b2_row8_col3, #T_042b2_row8_col4, #T_042b2_row8_col5, #T_042b2_row8_col6, #T_042b2_row8_col7, #T_042b2_row9_col0, #T_042b2_row9_col1, #T_042b2_row9_col3, #T_042b2_row9_col4, #T_042b2_row9_col5, #T_042b2_row9_col6, #T_042b2_row9_col7, #T_042b2_row10_col0, #T_042b2_row10_col1, #T_042b2_row10_col3, #T_042b2_row10_col4, #T_042b2_row10_col5, #T_042b2_row10_col6, #T_042b2_row10_col7, #T_042b2_row11_col0, #T_042b2_row11_col1, #T_042b2_row11_col3, #T_042b2_row11_col4, #T_042b2_row11_col5, #T_042b2_row11_col6, #T_042b2_row11_col7, #T_042b2_row12_col0, #T_042b2_row12_col1, #T_042b2_row12_col3, #T_042b2_row12_col4, #T_042b2_row12_col5, #T_042b2_row12_col6, #T_042b2_row12_col7, #T_042b2_row13_col0, #T_042b2_row13_col1, #T_042b2_row13_col3, #T_042b2_row13_col4, #T_042b2_row13_col5, #T_042b2_row13_col6, #T_042b2_row13_col7 {
#   text-align: left;
# }
# #T_042b2_row0_col1, #T_042b2_row0_col2, #T_042b2_row0_col3, #T_042b2_row0_col4, #T_042b2_row0_col5, #T_042b2_row0_col6, #T_042b2_row0_col7, #T_042b2_row1_col2, #T_042b2_row2_col2, #T_042b2_row3_col2, #T_042b2_row4_col2, #T_042b2_row5_col2, #T_042b2_row6_col2, #T_042b2_row7_col2, #T_042b2_row8_col2, #T_042b2_row9_col2, #T_042b2_row10_col2, #T_042b2_row11_col2, #T_042b2_row12_col2, #T_042b2_row13_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_042b2_row0_col8, #T_042b2_row1_col8, #T_042b2_row2_col8, #T_042b2_row3_col8, #T_042b2_row4_col8, #T_042b2_row5_col8, #T_042b2_row6_col8, #T_042b2_row7_col8, #T_042b2_row8_col8, #T_042b2_row10_col8, #T_042b2_row11_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_042b2_row9_col8, #T_042b2_row12_col8, #T_042b2_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_042b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_042b2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_042b2_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_042b2_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_042b2_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_042b2_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_042b2_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_042b2_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_042b2_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_042b2_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_042b2_level0_row0" class="row_heading level0 row0" >dt</th>
#       <td id="T_042b2_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_042b2_row0_col1" class="data row0 col1" >0.6274</td>
#       <td id="T_042b2_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_042b2_row0_col3" class="data row0 col3" >0.6274</td>
#       <td id="T_042b2_row0_col4" class="data row0 col4" >0.6474</td>
#       <td id="T_042b2_row0_col5" class="data row0 col5" >0.6263</td>
#       <td id="T_042b2_row0_col6" class="data row0 col6" >0.5655</td>
#       <td id="T_042b2_row0_col7" class="data row0 col7" >0.5689</td>
#       <td id="T_042b2_row0_col8" class="data row0 col8" >0.0220</td>
#     </tr>
#     <tr>
#       <th id="T_042b2_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_042b2_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_042b2_row1_col1" class="data row1 col1" >0.6262</td>
#       <td id="T_042b2_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_042b2_row1_col3" class="data row1 col3" >0.6262</td>
#       <td id="T_042b2_row1_col4" class="data row1 col4" >0.6286</td>
#       <td id="T_042b2_row1_col5" class="data row1 col5" >0.6199</td>
#       <td id="T_042b2_row1_col6" class="data row1 col6" >0.5641</td>
#       <td id="T_042b2_row1_col7" class="data row1 col7" >0.5662</td>
#       <td id="T_042b2_row1_col8" class="data row1 col8" >0.6310</td>
#     </tr>
#     <tr>
#       <th id="T_042b2_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_042b2_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_042b2_row2_col1" class="data row2 col1" >0.6262</td>
#       <td id="T_042b2_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_042b2_row2_col3" class="data row2 col3" >0.6262</td>
#       <td id="T_042b2_row2_col4" class="data row2 col4" >0.6449</td>
#       <td id="T_042b2_row2_col5" class="data row2 col5" >0.6248</td>
#       <td id="T_042b2_row2_col6" class="data row2 col6" >0.5641</td>
#       <td id="T_042b2_row2_col7" class="data row2 col7" >0.5674</td>
#       <td id="T_042b2_row2_col8" class="data row2 col8" >0.0830</td>
#     </tr>
#     <tr>
#       <th id="T_042b2_level0_row3" class="row_heading level0 row3" >knn</th>
#       <td id="T_042b2_row3_col0" class="data row3 col0" >K Neighbors Classifier</td>
#       <td id="T_042b2_row3_col1" class="data row3 col1" >0.6250</td>
#       <td id="T_042b2_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_042b2_row3_col3" class="data row3 col3" >0.6250</td>
#       <td id="T_042b2_row3_col4" class="data row3 col4" >0.6422</td>
#       <td id="T_042b2_row3_col5" class="data row3 col5" >0.6221</td>
#       <td id="T_042b2_row3_col6" class="data row3 col6" >0.5627</td>
#       <td id="T_042b2_row3_col7" class="data row3 col7" >0.5662</td>
#       <td id="T_042b2_row3_col8" class="data row3 col8" >0.0300</td>
#     </tr>
#     <tr>
#       <th id="T_042b2_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_042b2_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_042b2_row4_col1" class="data row4 col1" >0.6232</td>
#       <td id="T_042b2_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_042b2_row4_col3" class="data row4 col3" >0.6232</td>
#       <td id="T_042b2_row4_col4" class="data row4 col4" >0.6297</td>
#       <td id="T_042b2_row4_col5" class="data row4 col5" >0.6191</td>
#       <td id="T_042b2_row4_col6" class="data row4 col6" >0.5606</td>
#       <td id="T_042b2_row4_col7" class="data row4 col7" >0.5626</td>
#       <td id="T_042b2_row4_col8" class="data row4 col8" >0.7310</td>
#     </tr>
#     <tr>
#       <th id="T_042b2_level0_row5" class="row_heading level0 row5" >rf</th>
#       <td id="T_042b2_row5_col0" class="data row5 col0" >Random Forest Classifier</td>
#       <td id="T_042b2_row5_col1" class="data row5 col1" >0.6196</td>
#       <td id="T_042b2_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_042b2_row5_col3" class="data row5 col3" >0.6196</td>
#       <td id="T_042b2_row5_col4" class="data row5 col4" >0.6225</td>
#       <td id="T_042b2_row5_col5" class="data row5 col5" >0.6146</td>
#       <td id="T_042b2_row5_col6" class="data row5 col6" >0.5564</td>
#       <td id="T_042b2_row5_col7" class="data row5 col7" >0.5583</td>
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, random_state=123, splitter='best')

# %%
cf = plot_model(best_model, plot="confusion_matrix")

# %%
new_data = pd.read_csv('Petch(Dyna)\PetchBackward(Dyna).csv')
new_data = new_data.iloc[:, :-1]
new_data
# Out:
#     Time  imu0_ax  imu0_ay  imu0_az  imu1_ax  imu1_ay  imu1_az  imu2_ax  \
# 0      0    -4.79    -9.26     8.47     2.14    -4.90     5.07    -0.04
# 1      1    -2.34   -14.24    13.37     4.28    -9.81    10.13    -0.09
# 2      2     0.11   -19.21    18.27     6.42   -14.71    15.20    -0.13
# 3      3     2.57   -20.00    20.00     8.56   -19.61    20.00    -0.17
# 4      4     5.02   -20.00    20.00    10.70   -20.00    20.00    -0.22
# ..   ...      ...      ...      ...      ...      ...      ...      ...
# 95    95    20.00   -20.00    20.00    20.00   -20.00    20.00    -4.14
# 96    96    20.00   -20.00    20.00    20.00   -20.00    20.00    -4.18
# 97    97    20.00   -20.00    20.00    20.00   -20.00    20.00    -4.22
# 98    98    20.00   -20.00    20.00    20.00   -20.00    20.00    -4.27
# 99    99    20.00   -20.00    20.00    20.00   -20.00    20.00    -4.31
#
#     imu2_ay  imu2_az  imu3_ax  imu3_ay  imu3_az
# 0     -5.87     7.40    -0.42    -5.91     6.82
# 1    -11.73    14.81    -0.84   -11.82    13.64
# 2    -17.60    20.00    -1.26   -17.73    20.00
# 3    -20.00    20.00    -1.69   -20.00    20.00
# 4    -20.00    20.00    -2.11   -20.00    20.00
# ..      ...      ...      ...      ...      ...
# 95   -20.00    20.00   -20.00   -20.00    20.00
# 96   -20.00    20.00   -20.00   -20.00    20.00
# 97   -20.00    20.00   -20.00   -20.00    20.00
# 98   -20.00    20.00   -20.00   -20.00    20.00
# 99   -20.00    20.00   -20.00   -20.00    20.00
#
# [100 rows x 13 columns]

# %%
save_model(best_model, "maomaotrain")
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['imu0_ax', 'imu0_ay', 'imu0_az',
#                                               'imu1_ax', 'imu1_ay', 'imu1_az',
#                                               'imu2_ax', 'imu2_ay', 'imu2_az',
#                                               'imu3_ax', 'imu3_ay', 'imu3_az'],
#                                      transformer=SimpleI...
#                                                                missing_values=nan,
#                                                                strategy='most_frequent'))),
#                  ('trained_model',
#                   DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None,
#                                          criterion='gini', max_depth=None,
#                                          max_features=None, max_leaf_nodes=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          monotonic_cst=None, random_state=123,
#                                          splitter='best'))],
#           verbose=False),
#  'maomaotrain.pkl')

# %%
model = load_model('maomaotrain')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
predictions = model.predict(new_data)
print(predictions)
predictions.to_csv('predict1.csv', index=False)
# Out:
# 0         Left
# 1         Left
# 2         Down
# 3         Down
# 4         Down
#         ...
# 95    Backward
# 96    Backward
# 97    Backward
# 98    Backward
# 99          Up
# Name: Gesture, Length: 100, dtype: object
